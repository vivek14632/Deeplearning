# %%
import scipy
import numpy
from scipy import misc

image=misc.imread('/Users/tanaykarmarkar/Desktop/brd.jpg')

# change image dimension
image.shape

import matplotlib.pyplot as plt
plt.imshow(image)
plt.show()
print(image.shape)
print(numpy.amin(image))
numpy.amax(image)
x=numpy.random.rand(8,8)
plt.imshow(x)
plt.show()
# Out:
# (397, 600, 3)
# 0
