# %%
import pandas as pd
data_listing=pd.read_csv('/Users/jaideep/Desktop/Airbnb Project Files/listings 2.csv')
df_list = pd.DataFrame(data_listing)
df_list
# Out:
#              id                            listing_url       scrape_id  \
# 0      14831696  https://www.airbnb.com/rooms/14831696  20170402075052
# 1       3951251   https://www.airbnb.com/rooms/3951251  20170402075052
# 2      16590973  https://www.airbnb.com/rooms/16590973  20170402075052
# 3       9283701   https://www.airbnb.com/rooms/9283701  20170402075052
# 4       6458721   https://www.airbnb.com/rooms/6458721  20170402075052
# 5      14864447  https://www.airbnb.com/rooms/14864447  20170402075052
# 6      16306240  https://www.airbnb.com/rooms/16306240  20170402075052
# 7      15211538  https://www.airbnb.com/rooms/15211538  20170402075052
# 8       1261425   https://www.airbnb.com/rooms/1261425  20170402075052
# 9       5978154   https://www.airbnb.com/rooms/5978154  20170402075052
# 10     10691231  https://www.airbnb.com/rooms/10691231  20170402075052
# 11      8024854   https://www.airbnb.com/rooms/8024854  20170402075052
# ...

# %%
data_names=pd.read_csv('/Users/jaideep/Desktop/Airbnb Project Files/ImagesNames_split.csv')
df_names = pd.DataFrame(data_names)
del df_names['Unnamed: 0']
df_names_unique=pd.DataFrame(df_names.id.unique())
df_names_unique.columns = ['id']
df_names_unique
# Out:
#            id
# 0       70598
# 1       76459
# 2      264628
# 3      293337
# 4      515088
# 5      582382
# 6      591951
# 7      613088
# 8      667305
# 9      761411
# 10     854060
# 11     874340
# 12     886192
# 13     913470
# 14     916850
# 15     984134
# 16    1016999
# 17    1020573
# 18    1064499
# 19    1081307
# 20    1139498
# 21    1155432
# 22    1166169
# 23    1261425
# 24    1291054
# 25    1326658
# 26    1338633
# 27    1358042
# 28    1366058
# 29    1375612
# ..        ...
# 490  17129224
# 491  17194792
# 492  17196828
# 493  17251664
# 494  17365362
# 495  17446031
# 496  17462676
# 497  17472980
# 498  17487457
# 499  17488195
# 500  17519995
# 501  17548349
# 502  17557514
# 503  17585027
# 504  17612492
# 505  17634538
# 506  17643789
# 507  17654056
# 508  17791932
# 509  17799350
# 510  17800761
# 511  17809110
# 512  17835031
# 513  17838096
# 514  17848456
# 515  17886196
# 516  17890203
# 517  17891382
# 518  17905627
# 519  17932618
#
# ...

# %%
new_unique=pd.merge(df_list,df_names_unique, on='id', how='inner')
new_unique
# Out:
#            id                            listing_url       scrape_id  \
# 0    14831696  https://www.airbnb.com/rooms/14831696  20170402075052
# 1     3951251   https://www.airbnb.com/rooms/3951251  20170402075052
# 2     9283701   https://www.airbnb.com/rooms/9283701  20170402075052
# 3     6458721   https://www.airbnb.com/rooms/6458721  20170402075052
# 4    16306240  https://www.airbnb.com/rooms/16306240  20170402075052
# 5    15211538  https://www.airbnb.com/rooms/15211538  20170402075052
# 6     1261425   https://www.airbnb.com/rooms/1261425  20170402075052
# 7     5978154   https://www.airbnb.com/rooms/5978154  20170402075052
# 8     8024854   https://www.airbnb.com/rooms/8024854  20170402075052
# 9     6606330   https://www.airbnb.com/rooms/6606330  20170402075052
# 10    1551034   https://www.airbnb.com/rooms/1551034  20170402075052
# 11    2117111   https://www.airbnb.com/rooms/2117111  20170402075052
# 12    5317273   https://www.airbnb.com/rooms/5317273  20170402075052
# ...

# %%
new_unique.to_csv("/Users/jaideep/Desktop/Airbnb Project Files/Lisitng_merged_ListingsOnly_tab", sep='\t')
