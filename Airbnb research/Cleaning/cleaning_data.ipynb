# %%
import pandas as pd

# %%
data_listing=pd.read_csv('/Users/jaideep/Desktop/Airbnb Project Files/listings 2.csv')
df_list = pd.DataFrame(data)
df_list
# Out:
#              id                            listing_url       scrape_id  \
# 0      14831696  https://www.airbnb.com/rooms/14831696  20170402075052
# 1       3951251   https://www.airbnb.com/rooms/3951251  20170402075052
# 2      16590973  https://www.airbnb.com/rooms/16590973  20170402075052
# 3       9283701   https://www.airbnb.com/rooms/9283701  20170402075052
# 4       6458721   https://www.airbnb.com/rooms/6458721  20170402075052
# 5      14864447  https://www.airbnb.com/rooms/14864447  20170402075052
# 6      16306240  https://www.airbnb.com/rooms/16306240  20170402075052
# 7      15211538  https://www.airbnb.com/rooms/15211538  20170402075052
# 8       1261425   https://www.airbnb.com/rooms/1261425  20170402075052
# 9       5978154   https://www.airbnb.com/rooms/5978154  20170402075052
# 10     10691231  https://www.airbnb.com/rooms/10691231  20170402075052
# 11      8024854   https://www.airbnb.com/rooms/8024854  20170402075052
# ...

# %%
df["id"][106]
# Out:
# 14307719

# %%
data_names=pd.read_csv('/Users/jaideep/Desktop/Airbnb Project Files/ImagesNames_split.csv')
df_names = pd.DataFrame(data_names)
df_names
del df_names['Unnamed: 0']

# %%
df_names
# Out:
#            Image_Name        id
# 0         70598_0.png     70598
# 1         70598_1.png     70598
# 2         70598_2.png     70598
# 3         76459_0.png     76459
# 4         76459_1.png     76459
# 5         76459_2.png     76459
# 6         76459_3.png     76459
# 7         76459_4.png     76459
# 8         76459_5.png     76459
# 9         76459_6.png     76459
# 10        76459_7.png     76459
# 11        76459_8.png     76459
# 12        76459_9.png     76459
# 13       76459_10.png     76459
# 14       76459_11.png     76459
# 15       76459_12.png     76459
# 16       76459_13.png     76459
# 17       76459_14.png     76459
# 18       76459_15.png     76459
# 19       76459_16.png     76459
# 20       264628_0.png    264628
# 21       264628_1.png    264628
# 22       264628_2.png    264628
# 23       264628_3.png    264628
# 24       264628_4.png    264628
# 25       264628_5.png    264628
# 26       264628_6.png    264628
# 27       264628_7.png    264628
# ...

# %%
new=pd.merge(df_names,df_list, on='id', how='inner')

# %%
new
# Out:
#            Image_Name        id                            listing_url  \
# 0         70598_0.png     70598     https://www.airbnb.com/rooms/70598
# 1         70598_1.png     70598     https://www.airbnb.com/rooms/70598
# 2         70598_2.png     70598     https://www.airbnb.com/rooms/70598
# 3         76459_0.png     76459     https://www.airbnb.com/rooms/76459
# 4         76459_1.png     76459     https://www.airbnb.com/rooms/76459
# 5         76459_2.png     76459     https://www.airbnb.com/rooms/76459
# 6         76459_3.png     76459     https://www.airbnb.com/rooms/76459
# 7         76459_4.png     76459     https://www.airbnb.com/rooms/76459
# 8         76459_5.png     76459     https://www.airbnb.com/rooms/76459
# 9         76459_6.png     76459     https://www.airbnb.com/rooms/76459
# 10        76459_7.png     76459     https://www.airbnb.com/rooms/76459
# 11        76459_8.png     76459     https://www.airbnb.com/rooms/76459
# ...

# %%
new.to_csv("/Users/jaideep/Desktop/Airbnb Project Files/Lisitng_merged_tab", sep='\t')

# %%
new.to_csv("/Users/jaideep/Desktop/Airbnb Project Files/Lisitng_merged_comma", sep=',')
